# %% [markdown]
# 1. Importing Libraries
# 2. Importing Dataframes
# 3. If-Statements with user-defined functions
# 4. If-Statements with loc()
# 5. If-Statements with For-Loops

# %% [markdown]
# 1. Importing libraries

# %%
import pandas as pd
import numpy as np
import os
import pickle

# %% [markdown]
# 2. Importing dataframes

# %%
path = r'C:/Users/Alejandra/Documents/CF/Data Immersion/Achievement 4/06022025_Instacart Basket Analysis'

# %%
#Loading pickle file
df_ord_prod_merged = pd.read_pickle(os.path.join(path, '02_Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_ord_prod_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32404854   2977660   206209    prior            13                  1
# 32404855   2977660   206209    prior            13                  1
# 32404856   2977660   206209    prior            13                  1
# 32404857   2977660   206209    prior            13                  1
# 32404858   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
df = df_ord_prod_merged[:1000000] 
#Note: the colon before the number means everything from the beginning of the df until that number
#the colon after a number means everything from that number until the end.

# %%
df
# Out:
#         order_id  user_id eval_set  order_number  order_day_of_week  \
# 0        2539329        1    prior             1                  2
# 1        2539329        1    prior             1                  2
# 2        2539329        1    prior             1                  2
# 3        2539329        1    prior             1                  2
# 4        2539329        1    prior             1                  2
# ...          ...      ...      ...           ...                ...
# 999995   2789027     6474    prior             2                  3
# 999996   2789027     6474    prior             2                  3
# 999997   2789027     6474    prior             2                  3
# 999998   2789027     6474    prior             2                  3
# 999999   2789027     6474    prior             2                  3
#
#         order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# 0                       8                     NaN                  True
# ...

# %% [markdown]
# 3. If-Statements with user-defined functions

# %%
def price_label(row):

    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_2032\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product     673183
# Low-range product     314392
# High range product     12425
# Name: count, dtype: int64

# %%
df['prices'].value_counts(dropna=False)
# Out:
# prices
# 12.3    18880
# 10.3    15787
# 4.0     13935
# 6.3     13555
# 1.3     12858
#         ...
# 22.7        5
# 15.6        2
# 20.2        2
# 21.5        1
# 21.4        1
# Name: count, Length: 239, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
#This result can't be. Does not appear in the prices value counts.

# %%
df['price_range'='High range product'].value_counts(dropna=False)
# Out:
#   Cell In[30], line 1
#     df['price_range'='High range product'].value_counts(dropna=False)
#        ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
#Investigating data inconsistences
df_high_value_products=df[df['price_range']=='High range product']

# %%
df_high_value_products
# Out:
#         order_id  user_id eval_set  order_number  order_day_of_week  \
# 398      2086598        6    prior             1                  5
# 401       298250        6    prior             2                  4
# 436      2402008        7    prior             2                  1
# 465       121053        7    prior             3                  0
# 480      1695742        7    prior             4                  2
# ...          ...      ...      ...           ...                ...
# 999329   2442470     6468    prior             9                  1
# 999332   2442470     6468    prior             9                  1
# 999388     14321     6468    prior            13                  5
# 999394     14321     6468    prior            13                  5
# 999880   2720655     6472    prior            17                  2
#
#         order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# 398                    18                     NaN                  True
# ...

# %%
df_high_value_products['prices'].max()
# Out:
# 99999.0

# %%
#Creating subset for discrepant rows
discrepant_value = 99999.0
discrepant_row = df_high_value_products[df_high_value_products['prices'] == 99999.0]

# %%
discrepant_row
# Out:
#         order_id  user_id eval_set  order_number  order_day_of_week  \
# 128911    183964      873    prior             3                  0
# 128924   1851256      873    prior             4                  6
# 284218   1915696     1893    prior             1                  5
# 284229   2763293     1893    prior             2                  4
# 284252   2564805     1893    prior             4                  1
# 499076    949012     3339    prior             1                  1
# 499119    420057     3339    prior             2                  0
# 499141   1511997     3339    prior             3                  1
# 499158   1153448     3339    prior             4                  4
# 499180   2669259     3339    prior             5                  4
# 527458    965345     3531    prior            27                  2
# 767471   2291230     5034    prior             6                  1
# 767485   2324832     5034    prior             7                  6
# ...

# %%
discrepant_row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 128911 to 960509
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                15 non-null     int64
#  1   user_id                 15 non-null     int64
#  2   eval_set                15 non-null     object
#  3   order_number            15 non-null     int64
#  4   order_day_of_week       15 non-null     int64
#  5   order_hour_of_day       15 non-null     int64
#  6   days_since_prior_order  13 non-null     float64
#  7   days_prior_order_NaN    15 non-null     bool
#  8   days_prior_order_clean  15 non-null     float64
#  9   product_id              15 non-null     int64
#  10  add_to_cart_order       15 non-null     int64
#  11  reordered               15 non-null     int64
#  12  product_name            15 non-null     object
#  13  aisle_id                15 non-null     int64
# ...

# %%
df_high_value_products['prices'].describe()
# Out:
# count    12425.000000
# mean       311.294897
# std       3809.742521
# min         15.100000
# 25%         18.600000
# 50%         20.700000
# 75%         23.100000
# max      99999.000000
# Name: prices, dtype: float64

# %%
#Importing source df 'products', 'orders_products_prior' for further investigation: Is it wrangling or source error?
df_prods = pd.read_csv(os.path.join(path, '02_Data', 'Prepared Data', 'products_clean.csv'), index_col = False)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_prods['prices'].describe()
# Out:
# count    49672.000000
# mean         9.993282
# std        453.615536
# min          1.000000
# 25%          4.100000
# 50%          7.100000
# 75%         11.100000
# max      99999.000000
# Name: prices, dtype: float64

# %%
discrepant_product_value = 99999.0
discrepant_product = df_prods[df_prods['prices'] == discrepant_product_value]

# %%
discrepant_product
# Out:
#        Unnamed: 0  product_id           product_name  aisle_id  department_id  \
# 33649       33666       33664  2 % Reduced Fat  Milk        84             16
#
#         prices
# 33649  99999.0

# %%
#Conclusion: The inconsistency compared to the results in the reading portion of this exercise is due to the source dataframe.

# %%
df_prods['prices'].value_counts(dropna=False)
# Out:
# prices
# 2.5        470
# 5.3        458
# 6.2        451
# 2.6        447
# 5.4        444
#           ...
# 15.6         1
# 21.0         1
# 99999.0      1
# 14900.0      1
# 18.3         1
# Name: count, Length: 242, dtype: int64

# %%
#There are more than a single inconsistency. According to the results on the reading portion of the exercise, we have 5 inconsisten products. This translates to a df (the original 1 million subset) with actual high range products.

# %% [markdown]
# 4. If-Statements with loc()

# %%
df.loc[df['prices']>15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Alejandra\AppData\Local\Temp\ipykernel_2032\1812425363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices']>15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <=15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <=5, 'price_range_loc'] = 'Low-range product'

# %% [markdown]
# 5. If-Statements with For-Loops

# %%
df_ord_prod_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32404854   2977660   206209    prior            13                  1
# 32404855   2977660   206209    prior            13                  1
# 32404856   2977660   206209    prior            13                  1
# 32404857   2977660   206209    prior            13                  1
# 32404858   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
df_ord_prod_merged['order_day_of_week'].value_counts(dropna=False)
# Out:
# order_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in df_ord_prod_merged['order_day_of_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4: 
        result.append('Least busy')
    else: 
        result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ord_prod_merged['busiest_day']=result

# %%
df_ord_prod_merged['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# ##Exercise

# %%
#Adding 'price_range' to df_ord_prod_merged

# %%
df_ord_prod_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32404854   2977660   206209    prior            13                  1
# 32404855   2977660   206209    prior            13                  1
# 32404856   2977660   206209    prior            13                  1
# 32404857   2977660   206209    prior            13                  1
# 32404858   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
df
# Out:
#         order_id  user_id eval_set  order_number  order_day_of_week  \
# 0        2539329        1    prior             1                  2
# 1        2539329        1    prior             1                  2
# 2        2539329        1    prior             1                  2
# 3        2539329        1    prior             1                  2
# 4        2539329        1    prior             1                  2
# ...          ...      ...      ...           ...                ...
# 999995   2789027     6474    prior             2                  3
# 999996   2789027     6474    prior             2                  3
# 999997   2789027     6474    prior             2                  3
# 999998   2789027     6474    prior             2                  3
# 999999   2789027     6474    prior             2                  3
#
#         order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# 0                       8                     NaN                  True
# ...

# %%
df['order_day_of_week'].value_counts(dropna=False)
# Out:
# order_day_of_week
# 0    189676
# 1    169888
# 6    139752
# 5    133956
# 2    130531
# 3    118328
# 4    117869
# Name: count, dtype: int64

# %%
result = []

for value in df_ord_prod_merged['order_day_of_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4: 
        result.append('Least busy')
    else: 
        result.append('Regularly busy')

# %%
df_ord_prod_merged['price_range'] = df.apply(price_label, axis=1)

# %%
df_ord_prod_merged['price_range'].value_counts(dropna=False)
# Out:
# price_range
# NaN                   31404859
# Mid-range product       673183
# Low-range product       314392
# High range product       12425
# Name: count, dtype: int64

# %%
df_ord_prod_merged['prices'].value_counts(dropna=False)
# Out:
# prices
# 12.3    624261
# 10.3    510496
# 4.0     447272
# 6.3     438467
# 1.3     425691
#          ...
# 20.2       123
# 22.7        99
# 21.5        85
# 18.3        11
# 21.0         8
# Name: count, Length: 242, dtype: int64

# %%
df_ord_prod_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32404854   2977660   206209    prior            13                  1
# 32404855   2977660   206209    prior            13                  1
# 32404856   2977660   206209    prior            13                  1
# 32404857   2977660   206209    prior            13                  1
# 32404858   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
#result_2 is the variable where busiest days and slowest days are the 2 busiest and slowest respectively

result_2 = []

for value in df_ord_prod_merged['order_day_of_week']:
    if value in [0, 1]:
        result_2.append('Busiest days')
    elif value in [3, 4]: 
        result_2.append('Slowest days')
    else: 
        result_2.append('Regular days')

# %%
df_ord_prod_merged['busiest_days']=result_2

# %%
df_ord_prod_merged['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %%
df_ord_prod_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32404854   2977660   206209    prior            13                  1
# 32404855   2977660   206209    prior            13                  1
# 32404856   2977660   206209    prior            13                  1
# 32404857   2977660   206209    prior            13                  1
# 32404858   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
df_ord_prod_merged['order_day_of_week'].value_counts(dropna=False)
# Out:
# order_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
#Verifying operation
6204182+5660230
# Out:
# 11864412

# %%
3840534+3783802
# Out:
# 7624336

# %%
df_ord_prod_merged['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %%
df_ord_prod_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
df_ord_prod_merged['order_hour_of_day'].describe()
# Out:
# count    3.240486e+07
# mean     1.342515e+01
# std      4.246380e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      2.300000e+01
# Name: order_hour_of_day, dtype: float64

# %%
#result_3 is to assign the column 'busiest_period_of_day'
result_3 = []

for value in df_ord_prod_merged['order_hour_of_day']:
    if 10<= value <18:
        result_3.append('Most orders')
    elif 0<= value <6: 
        result_3.append('Fewest orders')
    else: 
        result_3.append('Average orders')

print(len(result_3)) #Check length after loop
# Out:
# 32404859

# %%
df_ord_prod_merged['busiest_period_of_day'] = result_3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 df_ord_prod_merged['busiest_period_of_day'] = result_3
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
# ...

# %%
#Troubleshooting: checking length
print(len(result_3))
print(len(df_ord_prod_merged))
# Out:
# 0
# 32404859

# %%
print(len(result_3)) #after adding checking count after loop on line 170
# Out:
# 32404859

# %%
#Creating column
df_ord_prod_merged['busiest_period_of_day'] = result_3

# %%
df_ord_prod_merged['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       20751522
# Regularly busy    11057009
# Least busy          596328
# Name: count, dtype: int64

# %%
df_ord_prod_merged
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32404854   2977660   206209    prior            13                  1
# 32404855   2977660   206209    prior            13                  1
# 32404856   2977660   206209    prior            13                  1
# 32404857   2977660   206209    prior            13                  1
# 32404858   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
#Export data to pkl
df_ord_prod_merged.to_pickle(os.path.join(path, '02_Data','Prepared Data', 'orders_products_merged_4.7.pkl'))
