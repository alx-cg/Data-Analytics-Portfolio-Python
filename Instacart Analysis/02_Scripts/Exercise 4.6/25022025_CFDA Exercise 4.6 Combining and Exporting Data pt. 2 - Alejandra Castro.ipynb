# %% [markdown]
# 1. Importing libraries
# 2. Importing dataframes
# 3. Merging dataframes df_ord_prod_combined and df_prods
# 4. Exporting dataframe in pickle format

# %% [markdown]
# 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os
import pickle

# %% [markdown]
# 2. Importing Dataframes

# %%
path = r'C:/Users/Alejandra/Documents/CF/Data Immersion/Achievement 4/06022025_Instacart Basket Analysis'

# %%
#Loading pickle file
df_ord_prod_combined = pd.read_pickle(os.path.join(path, '02_Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ord_prod_combined
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                  0   2539329        1    prior             1
# 1                  0   2539329        1    prior             1
# 2                  0   2539329        1    prior             1
# 3                  0   2539329        1    prior             1
# 4                  0   2539329        1    prior             1
# ...              ...       ...      ...      ...           ...
# 32434484     3421081   2977660   206209    prior            13
# 32434485     3421081   2977660   206209    prior            13
# 32434486     3421081   2977660   206209    prior            13
# 32434487     3421081   2977660   206209    prior            13
# 32434488     3421081   2977660   206209    prior            13
#
#           order_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                         2                  8                     NaN
# ...

# %%
df_ord_prod_combined.shape
# Out:
# (32434489, 14)

# %%
df_ord_prod_combined['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# 3. Merging dataframes df_ord_prod_combined and df_prods

# %%
#Loading df_prods
df_prods = pd.read_csv(os.path.join(path, '02_Data', 'Prepared Data', 'products_clean.csv'), index_col = False)

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
#Test merge without overwrite
pd.merge(df_ord_prod_combined, df_prods, on = ['product_id'])
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                    0   2539329        1    prior             1
# 1                    0   2539329        1    prior             1
# 2                    0   2539329        1    prior             1
# 3                    0   2539329        1    prior             1
# 4                    0   2539329        1    prior             1
# ...                ...       ...      ...      ...           ...
# 32404854       3421081   2977660   206209    prior            13
# 32404855       3421081   2977660   206209    prior            13
# 32404856       3421081   2977660   206209    prior            13
# 32404857       3421081   2977660   206209    prior            13
# 32404858       3421081   2977660   206209    prior            13
#
#           order_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                         2                  8                     NaN
# ...

# %%
#Dropping unnecessary columns 'Unnamed: 0', '_merge' from exercise in reading section. 
#Note, this command throws an error because I tried to rerun it with an extra column to drop after it had already dropped 'Unnamed'
df_ord_prod_combined= df_ord_prod_combined.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df_ord_prod_combined= df_ord_prod_combined.drop(columns=['Unnamed: 0'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df_ord_prod_combined
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32434484   2977660   206209    prior            13                  1
# 32434485   2977660   206209    prior            13                  1
# 32434486   2977660   206209    prior            13                  1
# 32434487   2977660   206209    prior            13                  1
# 32434488   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
df_ord_prod_combined = df_ord_prod_combined.drop(columns=['_merge'])

# %%
df_ord_prod_combined
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32434484   2977660   206209    prior            13                  1
# 32434485   2977660   206209    prior            13                  1
# 32434486   2977660   206209    prior            13                  1
# 32434487   2977660   206209    prior            13                  1
# 32434488   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
df_prods = df_prods.drop(columns=['Unnamed: 0'])

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_ords_prods_merge = df_ord_prod_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_ords_prods_merge
# Out:
#           order_id  user_id eval_set  order_number  order_day_of_week  \
# 0          2539329        1    prior             1                  2
# 1          2539329        1    prior             1                  2
# 2          2539329        1    prior             1                  2
# 3          2539329        1    prior             1                  2
# 4          2539329        1    prior             1                  2
# ...            ...      ...      ...           ...                ...
# 32404854   2977660   206209    prior            13                  1
# 32404855   2977660   206209    prior            13                  1
# 32404856   2977660   206209    prior            13                  1
# 32404857   2977660   206209    prior            13                  1
# 32404858   2977660   206209    prior            13                  1
#
#           order_hour_of_day  days_since_prior_order  days_prior_order_NaN  \
# ...

# %%
df_ords_prods_merge.shape
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# 4. Exporting dataframe in pickle format

# %%
#Export data to pkl
df_ords_prods_merge.to_pickle(os.path.join(path, '02_Data','Prepared Data', 'orders_products_merged.pkl'))
